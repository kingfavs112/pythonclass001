# %%
import pymysql

# %%
mydb = pymysql.connect(
    host = 'localhost',
    user = 'root',
    password='@Kenny8308'
)
mycursor = mydb.cursor()

# %%
mycursor.execute('show databases')
for x in mycursor:
    print(x)
# Out:
# ('accesswayprimebank',)
# ('cryptomarket',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('world',)

# %%
mydb = pymysql.connect(
    host = 'localhost',
    user = 'root',
    password='@Kenny8308',
    database='cryptomarket'
)
mycursor = mydb.cursor()

# %%
mycursor.execute('show columns from cryptoanalysis')
for x in mycursor:
    print(x)
# Out:
# ('CryptoSymbol', 'varchar(20)', 'NO', '', None, '')
# ('CryptoName', 'varchar(40)', 'NO', '', None, '')
# ('Price', 'int', 'NO', 'PRI', None, 'auto_increment')
# ('VolumeIncurrency', 'varchar(50)', 'NO', '', None, '')
# ('VolumeinCurrency24HR', 'varchar(50)', 'NO', '', None, '')
# ('TotalVoumeAllCurrencies24HR', 'varchar(50)', 'NO', '', None, '')
# ('CirculatingSupply', 'varchar(50)', 'NO', '', None, '')

# %%
import pymysql

# %%
mydb = pymysql.connect(
    host = 'localhost',
    user = 'root',
    password='@Kenny8308',
    database='cryptomarket'
)
mycursor = mydb.cursor()

# %%
mycursor.execute('show columns from cryptoanalysis')
for x in mycursor:
    print(x)
# Out:
# ('CryptoSymbol', 'varchar(20)', 'NO', '', None, '')
# ('CryptoName', 'varchar(40)', 'NO', '', None, '')
# ('Price', 'int', 'NO', 'PRI', None, 'auto_increment')
# ('VolumeIncurrency', 'varchar(50)', 'NO', '', None, '')
# ('VolumeinCurrency24HR', 'varchar(50)', 'NO', '', None, '')
# ('TotalVoumeAllCurrencies24HR', 'varchar(50)', 'NO', '', None, '')
# ('CirculatingSupply', 'varchar(50)', 'NO', '', None, '')

# %%
import pymysql

# %%
mydb = pymysql.connect(
    host = 'localhost',
    user = 'root',
    password='@Kenny8308',
    database='cryptomarket'
)
mycursor = mydb.cursor()

# %%
sql = 'insert into cryptoanalysis(Cryptosymbol,CryptoName,date,Open,High,Low,Close,AdjClose,Volume) values (%s,%s,%s,%s,%s,%s,%s,%s,%s)'
val = [('XRP-USD','Ripple/Usd','Oct 22, 2022','0.461216','0.469967','0.457287','0.464951','0.464951','983,595,904'),
       ('XRP-USD','Ripple/Usd','Oct 21, 2022','0.448004','0.461098','0.437806','0.461098','0.461098','1,644,912,255'),
      ('XRP-USD','Ripple/Usd','Oct 20, 2022','0.451223','0.463786','0.434426','0.448084','0.448084','1,712,992,943'),
      ('XRP-USD','Ripple/Usd','Oct 19, 2022','0.465988','0.466391','0.450080','0.451227','0.451227','1,434,466,929'),
      ('XRP-USD','Ripple/Usd','Oct 18, 2022','0.479918','0.483354','0.459844','0.465977','0.465977','1,380,317,427'),
      ('XRP-USD','Ripple/Usd','Oct 17, 2022','0.477011','0.481262','0.465333','0.479918','0.479918','1,476,868,338'),
      ('XRP-USD','Ripple/Usd','Oct 16, 2022','0.481530','0.487103','0.471813','0.477010','0.477010','1,028,960,255'),
      ('XRP-USD','Ripple/Usd','Oct 15, 2022','0.488957','0.489670','0.479980','0.481507','0.481507','842,401,177'),
      ('XRP-USD','Ripple/Usd','Oct 14, 2022','0.480806','0.509537','0.479304','0.488966','0.488966','2,184,144,921'),
      ('XRP-USD','Ripple/Usd','Oct 13, 2022','0.488353','0.489096','0.445024','0.480812','0.480812','2,840,221,578'),
      ('XRP-USD','Ripple/Usd','Oct 12, 2022','0.485413','0.494735','0.483756','0.488370','0.488370','1,375,026,360'),
      ('XRP-USD','Ripple/Usd','Oct 11, 2022','0.496661','0.500891','0.480910','0.485397','0.485397','2,303,743,073'),
      ('XRP-USD','Ripple/Usd','Oct 10, 2022','0.534029','0.537319','0.497014','0.497014','0.497014','2,359,086,772'),
      ('XRP-USD','Ripple/Usd','Oct 09, 2022','0.517149','0.541416','0.508167','0.534061','0.534061','1,789,206,998'),
      ('XRP-USD','Ripple/Usd','Oct 08, 2022','0.518225','0.527902','0.514383','0.517113','0.517113','1,771,062,053'),
      ('XRP-USD','Ripple/Usd','Oct 07, 2022','0.493277','0.521646','0.484205','0.518278','0.518278','2,627,481,992'),
      ('XRP-USD','Ripple/Usd','Oct 06, 2022','0.489699','0.504087','0.489372','0.493184','0.493184','1,913,140,571'),
      ('XRP-USD','Ripple/Usd','Oct 05, 2022','0.480121','0.499331','0.473405','0.489683','0.489683','2,480,530,357'),
      ('XRP-USD','Ripplr/Usd','Oct 04, 2022','0.462878','0.484598','0.452967','0.480174','0.480174','2,192,220,219'),
      ('XRP-USD','Ripple/Usd','Oct 03, 2022','0.448868','0.467568','0.439548','0.462879','0.462879','1,852,548,565'),
      ('XRP-USD','Ripple/Usd','Oct 02, 2022','0.475119','0.477434','0.448158','0.448850','0.448850','1,524,148,633'),
      ('XRP-USD','Ripple/Usd','Oct 01, 2022','0.479822','0.483517','0.469607','0.475110','0.475110','1,544,057,825')]
mycursor.executemany(sql,val)
mydb.commit()

# %%
mycursor.execute('select*from cryptoanalysis')
for x in mycursor:
    print(x)
# Out:
# ('XRP-USD', 'Ripple/Usd', 'Oct 22, 2022', '0.461216', '0.469967', '0.457287', '0.464951', '0.464951', '983,595,904')
# ('XRP-USD', 'Ripple/Usd', 'Oct 21, 2022', '0.448004', '0.461098', '0.437806', '0.461098', '0.461098', '1,644,912,255')
# ('XRP-USD', 'Ripple/Usd', 'Oct 20, 2022', '0.451223', '0.463786', '0.434426', '0.448084', '0.448084', '1,712,992,943')
# ('XRP-USD', 'Ripple/Usd', 'Oct 19, 2022', '0.465988', '0.466391', '0.450080', '0.451227', '0.451227', '1,434,466,929')
# ('XRP-USD', 'Ripple/Usd', 'Oct 18, 2022', '0.479918', '0.483354', '0.459844', '0.465977', '0.465977', '1,380,317,427')
# ('XRP-USD', 'Ripple/Usd', 'Oct 17, 2022', '0.477011', '0.481262', '0.465333', '0.479918', '0.479918', '1,476,868,338')
# ('XRP-USD', 'Ripple/Usd', 'Oct 16, 2022', '0.481530', '0.487103', '0.471813', '0.477010', '0.477010', '1,028,960,255')
# ('XRP-USD', 'Ripple/Usd', 'Oct 15, 2022', '0.488957', '0.489670', '0.479980', '0.481507', '0.481507', '842,401,177')
# ...

# %%
import pymysql

# %%
mydb = pymysql.connect(
    host = 'localhost',
    user = 'root',
    password='@Kenny8308',
    database='cryptomarket'
)
mycursor = mydb.cursor()

# %%
mycursor.execute('select*from cryptoanalysis')
for x in mycursor:
    print(x)
# Out:
# ('XRP-USD', 'Ripple/Usd', 'Oct 22, 2022', '0.461216', '0.469967', '0.457287', '0.464951', '0.464951', '983,595,904')
# ('XRP-USD', 'Ripple/Usd', 'Oct 21, 2022', '0.448004', '0.461098', '0.437806', '0.461098', '0.461098', '1,644,912,255')
# ('XRP-USD', 'Ripple/Usd', 'Oct 20, 2022', '0.451223', '0.463786', '0.434426', '0.448084', '0.448084', '1,712,992,943')
# ('XRP-USD', 'Ripple/Usd', 'Oct 19, 2022', '0.465988', '0.466391', '0.450080', '0.451227', '0.451227', '1,434,466,929')
# ('XRP-USD', 'Ripple/Usd', 'Oct 18, 2022', '0.479918', '0.483354', '0.459844', '0.465977', '0.465977', '1,380,317,427')
# ('XRP-USD', 'Ripple/Usd', 'Oct 17, 2022', '0.477011', '0.481262', '0.465333', '0.479918', '0.479918', '1,476,868,338')
# ('XRP-USD', 'Ripple/Usd', 'Oct 16, 2022', '0.481530', '0.487103', '0.471813', '0.477010', '0.477010', '1,028,960,255')
# ('XRP-USD', 'Ripple/Usd', 'Oct 15, 2022', '0.488957', '0.489670', '0.479980', '0.481507', '0.481507', '842,401,177')
# ...

# %%
sql = 'insert into cryptoanalysis(Cryptosymbol,CryptoName,date,Open,High,Low,Close,AdjClose,Volume) values (%s,%s,%s,%s,%s,%s,%s,%s,%s)'
val = [('DOT-USD','Polkadot/Usd','Oct 20, 2022','6.1070','6.1458','5.8506','5.8856','5.8856','217,674,629'),
      ('DOT-USD','Polkadot/Usd','Oct 19, 2022','6.1589','6.2494','6.0818','6.1067','6.1067','202,730,656'),
      ('DOT-USD','Polkadot/Usd','Oct 18, 2022','6.2530','6.2886','6.0872','6.1585','6.1585','194,319,444'),
      ('DOT-USD','Polkadot/Usd','Oct 17, 2022','6.1855','6.2735','6.1370','6.2531','6.2531','174,751,363'),
      ('DOT-USD','Polkadot/Usd','Oct 16, 2022','6.0526','6.2383','6.0523','6.1860','6.1860','148,292,090'),
      ('DOT-USD','Polkadot/Usd','Oct 15, 2022','6.0439','6.0937','6.0377','6.0529','6.0529','122,905,460'),
      ('DOT-USD','Polkadot/Usd','Oct 14, 2022','6.1165','6.2572','6.0205','6.0442','6.0442','196,246,835'),
      ('DOT-USD','Polkadot/Usd','Oct 13, 2022','6.1764','6.1777','5.7291','6.1169','6.1169','341,437,050'),
      ('DOT-USD','Polkadot/Usd','Oct 12, 2022','6.1795','6.2362','6.1469','6.1762','6.1762','141,021,054'),
      ('DOT-USD','Polkadot/Usd','Oct 11, 2022','6.2598','6.2606','6.1513','6.1794','6.1794','177,284,451'),
      ('DOT-USD','Polkadot/Usd','Oct 10, 2022','6.4758','6.5352','6.2595','6.2618','6.2618','195,297,282'),
      ('DOT-USD','Polkadot/Usd','Oct 09, 2022','6.3078','6.4883','6.2906','6.4752','6.4752','158,042,992'),
      ('DOT-USD','Polkadot/Usd','Oct 08, 2022','6.3318','6.3865','6.2772','6.3074','6.3074','125,045,671'),
      ('DOT-USD','Polkadot/Usd','Oct 07, 2022','6.3376','6.3849','6.2713','6.3318','6.3318','175,682,476'),
      ('DOT-USD','Polkadot/Usd','Oct 06, 2022','6.4348','6.5145','6.3266','6.3372','6.3372','203,714,376'),
      ('DOT-USD','Polkadot/Usd','Oct 05, 2022','6.4948','6.5022','6.2901','6.4352','6.4352','192,321,491'),
      ('DOT-USD','Polkadot/Usd','Oct 04, 2022','6.3788','6.5254','6.3510','6.4947','6.4947','201,625,888'),
      ('DOT-USD','Polkadot/Usd','Oct 03, 2022','6.1631','6.3948','6.1213','6.3797','6.3797','230,762,899'),
      ('DOT-USD','Polkadot/Usd','Oct 02, 2022','6.2724','6.3242','6.1569','6.1633','6.1633','200,153,796'),
      ('DOT-USD','Polkadot/Usd','Oct 01, 2022','6.3150','6.3312','6.2346','6.2723','6.2723','177,864,861')]
mycursor.executemany(sql,val)
mydb.commit()

# %%
mycursor.execute('select*from cryptoanalysis')
for x in mycursor:
    print(x)
# Out:
# ('XRP-USD', 'Ripple/Usd', 'Oct 22, 2022', '0.461216', '0.469967', '0.457287', '0.464951', '0.464951', '983,595,904')
# ('XRP-USD', 'Ripple/Usd', 'Oct 21, 2022', '0.448004', '0.461098', '0.437806', '0.461098', '0.461098', '1,644,912,255')
# ('XRP-USD', 'Ripple/Usd', 'Oct 20, 2022', '0.451223', '0.463786', '0.434426', '0.448084', '0.448084', '1,712,992,943')
# ('XRP-USD', 'Ripple/Usd', 'Oct 19, 2022', '0.465988', '0.466391', '0.450080', '0.451227', '0.451227', '1,434,466,929')
# ('XRP-USD', 'Ripple/Usd', 'Oct 18, 2022', '0.479918', '0.483354', '0.459844', '0.465977', '0.465977', '1,380,317,427')
# ('XRP-USD', 'Ripple/Usd', 'Oct 17, 2022', '0.477011', '0.481262', '0.465333', '0.479918', '0.479918', '1,476,868,338')
# ('XRP-USD', 'Ripple/Usd', 'Oct 16, 2022', '0.481530', '0.487103', '0.471813', '0.477010', '0.477010', '1,028,960,255')
# ('XRP-USD', 'Ripple/Usd', 'Oct 15, 2022', '0.488957', '0.489670', '0.479980', '0.481507', '0.481507', '842,401,177')
# ...

# %%
sql = 'insert into cryptoanalysis(Cryptosymbol,CryptoName,date,Open,High,Low,Close,AdjClose,Volume) values (%s,%s,%s,%s,%s,%s,%s,%s,%s)'
val = [('ETH-USD','Ethereum/Usd','Oct 20, 2022','1,314.84','1,333.09','1,303.31','1,329.91','1,329.91','7,858,483,712'),
      ('ETH-USD','Ethereum/Usd','Oct 19, 2022','1,310.56','1,312.44','1,283.97','1,285.74','1,285.74','8,350,692,785'),
      ('ETH-USD','Ethereum/Usd','Oct 18, 2022','1,331.67','1,339.09','1,291.66','1,310.45','1,310.45','10,416,747,806'),
      ('ETH-USD','Ethereum/Usd','Oct 17, 2022','1,306.31','1,335.65','1,297.45','1,331.71','1,331.71','9,401,189,650'),
      ('ETH-USD','Ethereum/Usd','Oct 16, 2022','1,275.01','1,312.63','1,275.01','1,306.30','1,306.30','7,491,625,206'),
      ('ETH-USD','Ethereum/Usd','Oct 15, 2022','1,297.31','1,300.75','1,268.47','1,274.87','1,274.87','6,798,512,624'),
      ('ETH-USD','Ethereum/Usd','Oct 14, 2022','1,288.05','1,339.74','1,285.38','1,297.42','1,297.42','13,113,767,755'),
      ('ETH-USD','Ethereum/Usd','Oct 13, 2022','1,294.92','1,297.56','1,209.28','1,288.12','1,288.12','17,499,038,202'),
      ('ETH-USD','Ethereum/Usd','Oct 12, 2022','1,279.73','1,303.08','1,277.53','1,294.91','1,294.91','8,355,638,578'),
      ('ETH-USD','Ethereum/Usd','Oct 11, 2022','1,291.11','1,296.27','1,272.74','1,279.58','1,279.58','9,274,845,260'),
      ('ETH-USD','Ethereum/Usd','Oct 10, 2022','1,322.62','1,335.66','1,291.34','1,291.34','1,291.34','8,794,491,050'),
      ('ETH-USD','Ethereum/Usd','Oct 09, 2022','1,315.46','1,327.67','1,309.34','1,322.60','1,322.60','5,486,230,123'),
      ('ETH-USD','Ethereum/Usd','Oct 08, 2022','1,332.37','1,335.95','1,307.07','1,315.50','1,315.50','5,804,676,208'),
      ('ETH-USD','Ethereum/Usd','Oct 07, 2022','1,351.84','1,359.33','1,321.75','1,332.52','1,332.52','10,061,619,355'),
      ('ETH-USD','Ethereum/Usd','Oct 06, 2022','1,352.81','1,380.40','1,349.45','1,351.71','1,351.71','12,033,514,861'),
      ('ETH-USD','Ethereum/Usd','Oct 05, 2022','1,361.97','1,362.45','1,320.86','1,352.84','1,352.84','9,774,451,820'),
      ('ETH-USD','Ethereum/Usd','Oct 04, 2022','1,323.28','1,364.97','1,320.08','1,362.13','1,362.13','10,139,774,963'),
      ('ETH-USD','Ethereum/Usd','Oct 03, 2022','1,276.16','1,326.55','1,271.15','1,323.44','1,323.44','10,153,070,907'),
      ('ETH-USD','Ethereum/Usd','Oct 02, 2022','1,311.75','1,316.33','1,275.34','1,276.09','1,276.09','7,578,351,650'),
      ('ETH-USD','Ethereum/Usd','Oct 01, 2022','1,328.19','1,332.52','1,306.10','1,311.64','1,311.64','6,227,961,237')]
mycursor.executemany(sql,val)
mydb.commit()

# %%
mycursor.execute('select*from cryptoanalysis')
for x in mycursor:
    print(x)
# Out:
# ('XRP-USD', 'Ripple/Usd', 'Oct 22, 2022', '0.461216', '0.469967', '0.457287', '0.464951', '0.464951', '983,595,904')
# ('XRP-USD', 'Ripple/Usd', 'Oct 21, 2022', '0.448004', '0.461098', '0.437806', '0.461098', '0.461098', '1,644,912,255')
# ('XRP-USD', 'Ripple/Usd', 'Oct 20, 2022', '0.451223', '0.463786', '0.434426', '0.448084', '0.448084', '1,712,992,943')
# ('XRP-USD', 'Ripple/Usd', 'Oct 19, 2022', '0.465988', '0.466391', '0.450080', '0.451227', '0.451227', '1,434,466,929')
# ('XRP-USD', 'Ripple/Usd', 'Oct 18, 2022', '0.479918', '0.483354', '0.459844', '0.465977', '0.465977', '1,380,317,427')
# ('XRP-USD', 'Ripple/Usd', 'Oct 17, 2022', '0.477011', '0.481262', '0.465333', '0.479918', '0.479918', '1,476,868,338')
# ('XRP-USD', 'Ripple/Usd', 'Oct 16, 2022', '0.481530', '0.487103', '0.471813', '0.477010', '0.477010', '1,028,960,255')
# ('XRP-USD', 'Ripple/Usd', 'Oct 15, 2022', '0.488957', '0.489670', '0.479980', '0.481507', '0.481507', '842,401,177')
# ...

# %%
sql = 'insert into cryptoanalysis(Cryptosymbol,CryptoName,date,Open,High,Low,Close,AdjClose,Volume) values (%s,%s,%s,%s,%s,%s,%s,%s,%s)'
val = [('BNB-USD','BNB/USD','Oct 20, 2022','271.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 19, 2022','271.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 18, 2022','271.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 17, 2022','271.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 16, 2022','271.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 15, 2022','271.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 14, 2022','271.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 13, 2022','278.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 12, 2022','276.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 11, 2022','277.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 10, 2022','270.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 09, 2022','275.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 08, 2022','272.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 07, 2022','273.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 06, 2022','278.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 05, 2022','279.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 04, 2022','278.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 03, 2022','276.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 02, 2022','274.95','273.29','267.86','269.27','269.27','539,795,617'),
      ('BNB-USD','BNB/USD','Oct 01, 2022','272.95','273.29','267.86','269.27','269.27','539,795,617'),]
mycursor.executemany(sql,val)
mydb.commit()

# %%
mycursor.execute('select*from cryptoanalysis')
for x in mycursor:
    print(x)
# Out:
# ('XRP-USD', 'Ripple/Usd', 'Oct 22, 2022', '0.461216', '0.469967', '0.457287', '0.464951', '0.464951', '983,595,904')
# ('XRP-USD', 'Ripple/Usd', 'Oct 21, 2022', '0.448004', '0.461098', '0.437806', '0.461098', '0.461098', '1,644,912,255')
# ('XRP-USD', 'Ripple/Usd', 'Oct 20, 2022', '0.451223', '0.463786', '0.434426', '0.448084', '0.448084', '1,712,992,943')
# ('XRP-USD', 'Ripple/Usd', 'Oct 19, 2022', '0.465988', '0.466391', '0.450080', '0.451227', '0.451227', '1,434,466,929')
# ('XRP-USD', 'Ripple/Usd', 'Oct 18, 2022', '0.479918', '0.483354', '0.459844', '0.465977', '0.465977', '1,380,317,427')
# ('XRP-USD', 'Ripple/Usd', 'Oct 17, 2022', '0.477011', '0.481262', '0.465333', '0.479918', '0.479918', '1,476,868,338')
# ('XRP-USD', 'Ripple/Usd', 'Oct 16, 2022', '0.481530', '0.487103', '0.471813', '0.477010', '0.477010', '1,028,960,255')
# ('XRP-USD', 'Ripple/Usd', 'Oct 15, 2022', '0.488957', '0.489670', '0.479980', '0.481507', '0.481507', '842,401,177')
# ...
